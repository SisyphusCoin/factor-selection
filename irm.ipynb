# %%
import pandas as pd
import sys
import os
parent_dir = os.path.dirname(os.path.abspath(''))
sys.path.append(parent_dir)

from utils import const

data_path = "../data/binance/BTCUSDT-1m-2024-all-with-indicators.csv"

df = pd.read_csv(data_path)
df["open_time"] = pd.to_datetime(df["open_time"], unit="ms")
df = df.set_index("open_time")

# %%
df["target"] = (df["close"].shift(-1) > df["close"]).astype(int)
df = df.dropna()

X = df[const.factor_cols]
y = df["target"]

X_train = X[X.index < const.split_time]
X_test = X[X.index >= const.split_time]
y_train = y[y.index < const.split_time]
y_test = y[y.index >= const.split_time]

# %%
# !which python
# !pip show torch
# Out:
# python not found
# zsh:1: command not found: pip

# %%
import torch

import torch.nn as nn
import torch.optim as optim


factor = const.factor_cols[0]
median = X_train[factor].median()
env1_idx = X_train[factor] <= median
env2_idx = X_train[factor] > median

envs = [
    (torch.tensor(X_train[env1_idx].values, dtype=torch.float32), torch.tensor(y_train[env1_idx].values, dtype=torch.float32)),
    (torch.tensor(X_train[env2_idx].values, dtype=torch.float32), torch.tensor(y_train[env2_idx].values, dtype=torch.float32)),
]

class MLP(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 16),
            nn.ReLU(),
            nn.Linear(16, 1)
        )

    def forward(self, x):
        return self.net(x).squeeze(-1)

def irm_penalty(logits, y):
    scale = torch.tensor(1.0, requires_grad=True)
    loss = nn.BCEWithLogitsLoss()(logits * scale, y)
    grad = torch.autograd.grad(loss, [scale], create_graph=True)[0]
    return torch.sum(grad**2)

input_dim = X_train.shape[1]
model = MLP(input_dim)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
n_steps = 3000
lambda_irm = 1e2

for step in range(n_steps):
    total_loss = 0
    penalty = 0
    for X_e, y_e in envs:
        logits = model(X_e)
        loss = nn.BCEWithLogitsLoss()(logits, y_e)
        total_loss += loss
        penalty += irm_penalty(logits, y_e)
    loss = total_loss / len(envs) + lambda_irm * penalty / len(envs)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    if step % 500 == 0:
        print(f"Step {step}, Loss: {loss.item():.4f}, Penalty: {penalty.item():.4f}")

with torch.no_grad():
    importance = model.net[0].weight.abs().sum(dim=0).cpu().numpy()
    factor_importance = sorted(zip(const.factor_cols, importance), key=lambda x: -x[1])
    for name, score in factor_importance:
        print(f"{name}: {score:.4f}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 37
#      35 input_dim = X_train.shape[1]
#      36 model = MLP(input_dim)
# ---> 37 optimizer = optim.Adam(model.parameters(), lr=1e-3)
#      38 n_steps = 3000
#      39 lambda_irm = 1e2
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/optim/adam.py:73, in Adam.__init__(self, params, lr, betas, eps, weight_decay, amsgrad, foreach, maximize, capturable, differentiable, fused)
#      59     raise ValueError(f"Invalid weight_decay value: {weight_decay}")
#      61 defaults = dict(
#      62     lr=lr,
#      63     betas=betas,
#    (...)
#      71     fused=fused,
#      72 )
# ---> 73 super().__init__(params, defaults)
#      75 if fused:
#      76     if differentiable:
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/optim/optimizer.py:367, in Optimizer.__init__(self, params, defaults)
#     364     param_groups = [{"params": param_groups}]
#     366 for param_group in param_groups:
# --> 367     self.add_param_group(cast(dict, param_group))
#     369 # Allows _cuda_graph_capture_health_check to rig a poor man's TORCH_WARN_ONCE in python,
#     370 # which I don't think exists
#     371 # https://github.com/pytorch/pytorch/issues/72948
#     372 self._warned_capturable_if_run_uncaptured = True
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/_compile.py:26, in _disable_dynamo.<locals>.inner(*args, **kwargs)
#      24 disable_fn = getattr(fn, "__dynamo_disable", None)
#      25 if disable_fn is None:
# ---> 26     import torch._dynamo
#      28     disable_fn = torch._dynamo.disable(fn, recursive)
#      29     fn.__dynamo_disable = disable_fn
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/_dynamo/__init__.py:2
#       1 import torch
# ----> 2 from . import convert_frame, eval_frame, resume_execution
#       3 from .backends.registry import list_backends, lookup_backend, register_backend
#       4 from .callback import callback_handler, on_compile_end, on_compile_start
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/_dynamo/convert_frame.py:48
#      45 from torch.utils._python_dispatch import _disable_current_modes
#      46 from torch.utils._traceback import format_traceback_short
# ---> 48 from . import config, exc, trace_rules
#      49 from .backends.registry import CompilerFn
#      50 from .bytecode_analysis import remove_dead_code, remove_pointless_jumps
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/_dynamo/trace_rules.py:52
#      49 from .resume_execution import TORCH_DYNAMO_RESUME_IN_PREFIX
#      50 from .utils import getfile, hashable, NP_SUPPORTED_MODULES, unwrap_if_wrapper
# ---> 52 from .variables import (
#      53     BuiltinVariable,
#      54     FunctorchHigherOrderVariable,
#      55     NestedUserFunctionVariable,
#      56     SkipFunctionVariable,
#      57     TorchInGraphFunctionVariable,
#      58     UserFunctionVariable,
#      59     UserMethodVariable,
#      60 )
#      63 if typing.TYPE_CHECKING:
#      64     from .variables.base import VariableTracker
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/_dynamo/variables/__init__.py:38
#      30 from .distributed import BackwardHookVariable, DistributedVariable, PlacementVariable
#      31 from .functions import (
#      32     FunctoolsPartialVariable,
#      33     NestedUserFunctionVariable,
#    (...)
#      36     UserMethodVariable,
#      37 )
# ---> 38 from .higher_order_ops import (
#      39     FunctorchHigherOrderVariable,
#      40     TorchHigherOrderOperatorVariable,
#      41 )
#      42 from .iter import (
#      43     CountIteratorVariable,
#      44     CycleIteratorVariable,
#    (...)
#      47     RepeatIteratorVariable,
#      48 )
#      49 from .lazy import LazyVariableTracker
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/_dynamo/variables/higher_order_ops.py:14
#      12 import torch.fx
#      13 import torch.nn
# ---> 14 import torch.onnx.operators
#      15 from torch._dynamo.utils import get_fake_value
#      16 from torch._dynamo.variables import ConstantVariable
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/__init__.py:11
#       3 from torch._C import _onnx as _C_onnx
#       4 from torch._C._onnx import (
#       5     _CAFFE2_ATEN_FALLBACK,
#       6     OperatorExportTypes,
#       7     TensorProtoDataType,
#       8     TrainingMode,
#       9 )
# ---> 11 from . import (  # usort:skip. Keep the order instead of sorting lexicographically
#      12     _deprecation,
#      13     errors,
#      14     symbolic_caffe2,
#      15     symbolic_helper,
#      16     symbolic_opset7,
#      17     symbolic_opset8,
#      18     symbolic_opset9,
#      19     symbolic_opset10,
#      20     symbolic_opset11,
#      21     symbolic_opset12,
#      22     symbolic_opset13,
#      23     symbolic_opset14,
#      24     symbolic_opset15,
#      25     symbolic_opset16,
#      26     symbolic_opset17,
#      27     symbolic_opset18,
#      28     symbolic_opset19,
#      29     symbolic_opset20,
#      30     utils,
#      31 )
#      33 # TODO(After 1.13 release): Remove the deprecated SymbolicContext
#      34 from ._exporter_states import ExportTypes, SymbolicContext
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/errors.py:9
#       7 from torch import _C
#       8 from torch.onnx import _constants
# ----> 9 from torch.onnx._internal import diagnostics
#      11 __all__ = [
#      12     "OnnxExporterError",
#      13     "OnnxExporterWarning",
#    (...)
#      16     "UnsupportedOperatorError",
#      17 ]
#      20 class OnnxExporterWarning(UserWarning):
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/_internal/diagnostics/__init__.py:1
# ----> 1 from ._diagnostic import (
#       2     create_export_diagnostic_context,
#       3     diagnose,
#       4     engine,
#       5     export_context,
#       6     ExportDiagnosticEngine,
#       7     TorchScriptOnnxExportDiagnostic,
#       8 )
#       9 from ._rules import rules
#      10 from .infra import levels
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/_internal/diagnostics/_diagnostic.py:12
#       8 from typing import List, Optional
#      10 import torch
# ---> 12 from torch.onnx._internal.diagnostics import infra
#      13 from torch.onnx._internal.diagnostics.infra import formatter, sarif
#      14 from torch.onnx._internal.diagnostics.infra.sarif import version as sarif_version
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/_internal/diagnostics/infra/__init__.py:1
# ----> 1 from ._infra import (
#       2     DiagnosticOptions,
#       3     Graph,
#       4     Invocation,
#       5     Level,
#       6     levels,
#       7     Location,
#       8     Rule,
#       9     RuleCollection,
#      10     Stack,
#      11     StackFrame,
#      12     Tag,
#      13     ThreadFlowLocation,
#      14 )
#      15 from .context import Diagnostic, DiagnosticContext, RuntimeErrorWithDiagnostic
#      17 __all__ = [
#      18     "Diagnostic",
#      19     "DiagnosticContext",
#    (...)
#      32     "ThreadFlowLocation",
#      33 ]
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/_internal/diagnostics/infra/_infra.py:11
#       8 import logging
#       9 from typing import FrozenSet, List, Mapping, Optional, Sequence, Tuple
# ---> 11 from torch.onnx._internal.diagnostics.infra import formatter, sarif
#      14 class Level(enum.IntEnum):
#      15     """The level of a diagnostic.
#      16
#      17     This class is used to represent the level of a diagnostic. The levels are defined
#    (...)
#      34         Level.ERROR = logging.ERROR = 40
#      35     """
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/_internal/diagnostics/infra/formatter.py:10
#       7 from typing import Any, Callable, Dict, List, Optional, Union
#       9 from torch._logging import LazyString
# ---> 10 from torch.onnx._internal import _beartype
#      11 from torch.onnx._internal.diagnostics.infra import sarif
#      14 # A list of types in the SARIF module to support pretty printing.
#      15 # This is solely for type annotation for the functions below.
#
# File /opt/miniconda3/lib/python3.12/site-packages/torch/onnx/_internal/_beartype.py:15
#      12 from types import ModuleType
#      14 try:
# ---> 15     import beartype as _beartype_lib  # type: ignore[import]
#      16     from beartype import roar as _roar  # type: ignore[import]
#      18     # Beartype warns when we import from typing because the types are deprecated
#      19     # in Python 3.9. But there will be a long time until we can move to using
#      20     # the native container types for type annotations (when 3.9 is the lowest
#      21     # supported version). So we silence the warning.
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/__init__.py:158
#     150 _init()
#     152 # ....................{ IMPORTS ~ non-meta                 }....................
#     153 # Import from the "beartype" codebase *AFTER* initializing this submodule above,
#     154 # thus validating the active Python interpreter to satisfy requirements.
#     155
#     156 # Publicize the private @beartype._decor.beartype decorator as
#     157 # @beartype.beartype, preserving all implementation details as private.
# --> 158 from beartype._decor.decormain import (
#     159     beartype as beartype)
#     161 # Publicize all top-level configuration attributes required to configure the
#     162 # @beartype.beartype decorator.
#     163 from beartype._conf.confcls import (
#     164     BeartypeConf as BeartypeConf)
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_decor/decormain.py:112
#     107         return obj
#     108 # Else, the active Python interpreter is in a standard runtime state. In this
#     109 # case, define the @beartype decorator in the standard way.
#     110 else:
#     111     # This is where @beartype *REALLY* lives. Grep here for all the goods.
# --> 112     from beartype._decor.decorcache import beartype
#     114 # ....................{ DECORATORS ~ doc                   }....................
#     115 # Document the @beartype decorator with the same documentation regardless of
#     116 # which of the above implementations currently implements that decorator.
#     117 beartype.__doc__ = (
#     118     '''
#     119     Decorate the passed **beartypeable** (i.e., pure-Python callable or
#    (...)
#     230     '''
#     231 )
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_decor/decorcache.py:38
#      32 from beartype._conf.conftest import die_unless_conf
#      33 from beartype._data.hint.datahinttyping import (
#      34     BeartypeConfedDecorator,
#      35     BeartypeReturn,
#      36     BeartypeableT,
#      37 )
# ---> 38 from beartype._decor.decorcore import beartype_object
#      40 # ....................{ DECORATORS                         }....................
#      41 #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#      42 # CAUTION: Synchronize the signature of this non-identity decorator with the
#    (...)
#      46 # defines the docstring for this decorator.
#      47 #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#      48 def beartype(
#      49     # Optional positional or keyword parameters.
#      50     obj: Optional[BeartypeableT] = None,
#    (...)
#      56
#      57     # If this configuration is invalid, raise an exception.
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_decor/decorcore.py:26
#      21 from beartype._conf.confcls import BeartypeConf
#      22 from beartype._data.hint.datahinttyping import (
#      23     BeartypeableT,
#      24     TypeWarning,
#      25 )
# ---> 26 from beartype._decor._nontype.decornontype import beartype_nontype
#      27 from beartype._decor._decortype import beartype_type
#      28 from beartype._util.cls.utilclstest import is_type_subclass
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_decor/_nontype/decornontype.py:24
#      16 from beartype.roar import (
#      17     BeartypeDecorWrappeeException,
#      18     BeartypeDecorWrapperException,
#      19 )
#      20 from beartype.typing import (
#      21     Optional,
#      22     no_type_check,
#      23 )
# ---> 24 from beartype._check.metadata.metadecor import (
#      25     cull_beartype_call,
#      26     make_beartype_call,
#      27 )
#      28 from beartype._conf.confcls import BeartypeConf
#      29 from beartype._conf.confenum import BeartypeStrategy
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_check/metadata/metadecor.py:25
#      23 from beartype._cave._cavefast import CallableCodeObjectType
#      24 from beartype._cave._cavemap import NoneTypeOr
# ---> 25 from beartype._check.forward.fwdscope import BeartypeForwardScope
#      26 from beartype._conf.confcls import BeartypeConf
#      27 from beartype._data.hint.datahintpep import DictStrToHint
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_check/forward/fwdscope.py:38
#      36 from beartype.typing import Type
#      37 from beartype._data.hint.datahinttyping import LexicalScope
# ---> 38 from beartype._check.forward.reference.fwdrefabc import (
#      39     _BeartypeForwardRefIndexableABC)
#      40 from beartype._check.forward.reference.fwdrefmake import (
#      41     make_forwardref_indexable_subtype)
#      42 from beartype._util.func.utilfuncframe import (
#      43     get_frame_caller_module_name_or_none,
#      44     is_frame_caller_beartype,
#      45 )
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_check/forward/reference/fwdrefabc.py:25
#      17 from beartype.typing import (
#      18     NoReturn,
#      19     Optional,
#      20     Type,
#      21 )
#      22 from beartype._data.hint.datahinttyping import (
#      23     LexicalScope,
#      24 )
# ---> 25 from beartype._check.forward.reference.fwdrefmeta import BeartypeForwardRefMeta
#      27 # ....................{ SUPERCLASSES                       }....................
#      28 #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
#      29 # CAUTION: The names of *ALL* class variables declared below *MUST* be both:
#    (...)
#      37
#      38 #FIXME: Unit test us up, please.
#      39 class BeartypeForwardRefABC(object, metaclass=BeartypeForwardRefMeta):
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_check/forward/reference/fwdrefmeta.py:22
#      19 from beartype._util.cls.pep.clspep3119 import (
#      20     die_unless_object_isinstanceable)
#      21 # from beartype._util.func.utilfuncframe import is_frame_caller_beartype
# ---> 22 from beartype._util.hint.pep.proposal.pep484585.generic.pep484585genget import (
#      23     get_hint_pep484585_generic_type)
#      24 from beartype._util.hint.pep.proposal.pep484585.generic.pep484585gentest import (
#      25     is_hint_pep484585_generic)
#      26 from beartype._util.module.utilmodimport import import_module_attr
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_util/hint/pep/proposal/pep484585/generic/pep484585genget.py:30
#      28 from beartype._data.hint.datahinttyping import TypeException
#      29 from beartype._util.cache.utilcachecall import callable_cached
# ---> 30 from beartype._util.hint.pep.proposal.pep484.pep484generic import (
#      31     get_hint_pep484_generic_bases_unerased)
#      32 from beartype._util.hint.pep.proposal.pep484.pep484typevar import (
#      33     is_hint_pep484_typevar)
#      34 from beartype._util.hint.pep.proposal.pep585 import (
#      35     get_hint_pep585_generic_bases_unerased,
#      36     is_hint_pep585_generic,
#      37 )
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_util/hint/pep/proposal/pep484/pep484generic.py:187
#     149     return (
#     150         # If the active Python interpreter targets Python >= 3.11, a subclass
#     151         # test suffices to detect a PEP 484-compliant unsubscripted generic;
#    (...)
#     183         )
#     184     )
#     186 # ....................{ GETTERS                            }....................
# --> 187 @callable_cached
#     188 def get_hint_pep484_generic_bases_unerased(
#     189     # Mandatory parameters.
#     190     hint: Any,
#     191
#     192     # Optional parameters.
#     193     exception_cls: TypeException = BeartypeDecorHintPep484Exception,
#     194     exception_prefix: str = '',
#     195 ) -> tuple:
#     196     '''
#     197     Tuple of all unerased :mod:`typing` **pseudo-superclasses** (i.e.,
#     198     :mod:`typing` objects originally listed as superclasses prior to their
#    (...)
#     252         Further details.
#     253     '''
#     255     #FIXME: This tuple appears to be implemented erroneously -- at least under
#     256     #Python 3.7, anyway. Although this tuple is implemented correctly for the
#     257     #common case of user-defined types directly subclassing "typing" types,
#    (...)
#     374
#     375     # Avoid circular import dependencies.
#
# File /opt/miniconda3/lib/python3.12/site-packages/beartype/_util/cache/utilcachecall.py:34, in callable_cached(func)
#      31 from functools import wraps
#      33 # ....................{ DECORATORS ~ callable              }....................
# ---> 34 def callable_cached(func: CallableT) -> CallableT:
#      35     '''
#      36     **Memoize** (i.e., efficiently re-raise all exceptions previously raised by
#      37     the decorated callable when passed the same parameters (i.e., parameters
#    (...)
#     150         ``*args``).
#     151     '''
#     152     assert callable(func), f'{repr(func)} not callable.'
#
# KeyboardInterrupt:
